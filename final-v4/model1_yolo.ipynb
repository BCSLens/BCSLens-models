# %%
import os
import csv
import cv2
from ultralytics import YOLO

MODEL_PATH = "BCSLens-models/yolo12n.pt"
IMAGE_FOLDER = "BCSLens-models/bcs_dataset"
OUTPUT_CSV = "prediction_results.csv"

model = YOLO(MODEL_PATH)

def predict_animal(image_path):
    img = cv2.imread(image_path)
    if img is None:
        return []

    results = model.predict(img, imgsz=640)
    predictions = []

    for r in results:
        boxes = r.boxes.xyxy.cpu().numpy()
        class_ids = r.boxes.cls.cpu().numpy()
        confidences = r.boxes.conf.cpu().numpy()

        for cls_id, conf, box in zip(class_ids, confidences, boxes):
            label = model.names[int(cls_id)]
            # กรองเฉพาะ dog หรือ cat
            if label.lower() in ["dog", "cat"]:
                predictions.append({
                    "label": label,
                    "confidence": float(conf),
                    "bbox": box.tolist()
                })
    return predictions

def predict_folder(image_folder, output_csv):
    image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["image_name", "label", "confidence", "bbox"])

        for img_name in image_files:
            img_path = os.path.join(image_folder, img_name)
            preds = predict_animal(img_path)

            if preds:
                for p in preds:
                    writer.writerow([img_name, p["label"], p["confidence"], p["bbox"]])
            else:
                writer.writerow([img_name, "No detection", "", ""])

            print(f"Processed {img_name}")

    print(f"Prediction completed. Results saved to {output_csv}")


if __name__ == "__main__":
    predict_folder(IMAGE_FOLDER, OUTPUT_CSV)
# Out:
# 0: 480x640 1 dog, 73.6ms
# Speed: 1.9ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_2565 - Pasavit TAPEN.jpeg
#
# 0: 480x640 1 person, 1 dog, 71.0ms
# Speed: 1.5ms preprocess, 71.0ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083059 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 1 dog, 52.8ms
# Speed: 2.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_090434 - Khomson Satchasataporn.jpg
#
# 0: 480x640 3 persons, 1 dog, 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_094326 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 dog, 2 bottles, 1 chair, 56.3ms
# Speed: 1.7ms preprocess, 56.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_083110 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 cat, 1 suitcase, 64.4ms
# Speed: 1.9ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_113405 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 1 bed, 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_2718 - Pasavit TAPEN.jpeg
#
# 0: 480x640 1 cat, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084908 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 58.0ms
# Speed: 1.9ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_094710 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 cat, 58.7ms
# Speed: 4.6ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_8981 - Patchareenat N.jpeg
#
# 0: 480x640 3 persons, 1 cat, 1 chair, 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_100556 - Khomson Satchasataporn.jpg
#
# 0: 480x640 4 persons, 1 cat, 1 handbag, 1 clock, 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_121137 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 dogs, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092512 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 dog, 50.4ms
# Speed: 1.9ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083959 - Khomson Satchasataporn (1).jpg
#
# 0: 480x640 3 persons, 1 dog, 53.7ms
# Speed: 1.8ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_113408 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 60.7ms
# Speed: 1.8ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_094713 - Khomson Satchasataporn.jpg
#
# 0: 480x640 4 persons, 1 dog, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_082954 - Khomson Satchasataporn.jpg
#
# 0: 480x640 3 persons, 1 car, 1 cat, 1 dog, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_100629 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_091435 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0581 - Pakkaphan SAMAKWONGPANICH.jpeg
#
# 0: 480x640 1 cat, 1 book, 54.1ms
# Speed: 1.8ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_090406 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 cat, 1 dog, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_082932 - Khomson Satchasataporn.jpg
#
# 0: 480x640 (no detections), 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_130523 - Khomson Satchasataporn.jpg
#
# 0: 480x640 3 persons, 1 dog, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083106 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 person, 1 teddy bear, 53.4ms
# Speed: 1.6ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_101251 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 2 chairs, 1 couch, 1 bed, 54.5ms
# Speed: 2.2ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_2719 - Pasavit TAPEN.jpeg
#
# 0: 640x480 1 dog, 1 bear, 54.1ms
# Speed: 1.7ms preprocess, 54.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_103106 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 dog, 2 bottles, 1 chair, 61.7ms
# Speed: 1.7ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_083110 - Khomson Satchasataporn copy.jpg
#
# 0: 480x640 2 persons, 1 dog, 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083323 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 1 couch, 56.9ms
# Speed: 1.7ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084932 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 cat, 1 dog, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092151 - Khomson Satchasataporn.jpg
#
# 0: 480x640 3 persons, 1 dog, 49.5ms
# Speed: 1.7ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_102746 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_0927 - Ratthawit Rattanawai.jpeg
#
# 0: 640x480 1 car, 1 cat, 1 bed, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0918 - Ratthawit Rattanawai.jpeg
#
# 0: 480x640 6 persons, 2 cats, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_102251 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 1 carrot, 49.2ms
# Speed: 1.4ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_2716 - Pasavit TAPEN.jpeg
#
# 0: 480x640 1 cat, 1 chair, 1 potted plant, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_082939 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 cat, 1 bottle, 63.9ms
# Speed: 1.7ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_092105 - Khomson Satchasataporn.jpg
#
# 0: 640x480 4 persons, 1 dog, 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_122519 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 car, 1 cat, 1 laptop, 1 book, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_113758 - Khomson Satchasataporn.jpg
#
# 0: 640x480 5 persons, 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_094320 - Khomson Satchasataporn.jpg
#
# 0: 480x640 3 persons, 1 dog, 1 clock, 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092057 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 cat, 1 laptop, 97.7ms
# Speed: 1.4ms preprocess, 97.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_113818 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 bicycles, 1 dog, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_9100 - PANNAWAT SINTHUBTHONG.jpeg
#
# 0: 480x640 2 persons, 1 dog, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_103110 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 car, 1 cat, 1 cup, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_102205 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084915 - Khomson Satchasataporn.jpg
#
# 0: 480x640 4 persons, 1 cat, 1 bowl, 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_100103 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_094310 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_130516 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0580 - Pakkaphan SAMAKWONGPANICH.jpeg
#
# 0: 480x640 1 person, 2 dogs, 1 chair, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_095005 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 53.5ms
# Speed: 1.6ms preprocess, 53.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084003 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 car, 1 cat, 1 suitcase, 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_100607 - Khomson Satchasataporn.jpg
#
# 0: 640x480 3 persons, 1 dog, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_123603 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 suitcase, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084722 - Khomson Satchasataporn.jpg
#
# 0: 480x640 9 persons, 1 dog, 53.4ms
# Speed: 1.6ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092518 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 54.6ms
# Speed: 1.7ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0578 - Pakkaphan SAMAKWONGPANICH.jpeg
#
# 0: 480x640 1 person, 1 cat, 1 bed, 1 tv, 52.7ms
# Speed: 2.2ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_8982 - Patchareenat N.jpeg
#
# 0: 480x640 1 person, 1 cat, 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092822 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 bear, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_2570 - Pasavit TAPEN.jpeg
#
# 0: 480x640 3 persons, 1 cat, 61.1ms
# Speed: 1.5ms preprocess, 61.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_090443 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 1 couch, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_2715 - Pasavit TAPEN.jpeg
#
# 0: 640x480 1 cat, 1 suitcase, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0932 - Ratthawit Rattanawai.jpeg
#
# 0: 480x640 1 cat, 1 bed, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083313 - Khomson Satchasataporn.jpg
#
# 0: 480x640 4 persons, 1 dog, 1 bear, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_101311 - Khomson Satchasataporn.jpg
#
# 0: 640x480 (no detections), 58.8ms
# Speed: 1.6ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_8980 - Patchareenat N.jpeg
#
# 0: 480x640 1 cat, 59.3ms
# Speed: 1.8ms preprocess, 59.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_091854 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 59.0ms
# Speed: 2.1ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_111449 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 car, 1 dog, 80.5ms
# Speed: 1.5ms preprocess, 80.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_092852 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 cat, 1 clock, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_091416 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_122515 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 person, 1 cat, 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092849 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 61.3ms
# Speed: 1.7ms preprocess, 61.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084718 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 cat, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0915 - Ratthawit Rattanawai.jpeg
#
# 0: 480x640 1 cat, 63.1ms
# Speed: 1.7ms preprocess, 63.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083300 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 60.8ms
# Speed: 1.7ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_9099 - PANNAWAT SINTHUBTHONG.jpeg
#
# 0: 640x480 1 dog, 55.3ms
# Speed: 1.6ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_2571 - Pasavit TAPEN.jpeg
#
# 0: 480x640 1 person, 1 cat, 62.0ms
# Speed: 1.8ms preprocess, 62.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_123548 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 1 bed, 54.4ms
# Speed: 1.7ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_100112 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 58.4ms
# Speed: 1.7ms preprocess, 58.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_1180 - Thanaporn PANWADVANISH.jpeg
#
# 0: 480x640 5 persons, 1 dog, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_094723 - Khomson Satchasataporn.jpg
#
# 0: 480x640 4 persons, 1 dog, 1 book, 55.6ms
# Speed: 1.5ms preprocess, 55.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_092508 - Khomson Satchasataporn.jpg
#
# 0: 480x640 2 persons, 1 dog, 54.6ms
# Speed: 1.5ms preprocess, 54.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083948 - Khomson Satchasataporn (1).jpg
#
# 0: 480x640 1 person, 1 cat, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_091900 - Khomson Satchasataporn.jpg
#
# 0: 640x480 (no detections), 56.7ms
# Speed: 1.9ms preprocess, 56.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_130508 - Khomson Satchasataporn.jpg
#
# 0: 640x480 2 persons, 1 dog, 1 bed, 53.9ms
# Speed: 1.6ms preprocess, 53.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_095015 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 dog, 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_0577 - Pakkaphan SAMAKWONGPANICH.jpeg
#
# 0: 480x640 1 dog, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_2569 - Pasavit TAPEN.jpeg
#
# 0: 480x640 1 person, 1 cat, 1 bed, 1 tv, 55.5ms
# Speed: 1.6ms preprocess, 55.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_8984 - Patchareenat N.jpeg
#
# 0: 480x640 1 cat, 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_091918 - Khomson Satchasataporn.jpg
#
# 0: 640x480 3 persons, 1 dog, 1 bottle, 61.7ms
# Speed: 1.4ms preprocess, 61.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_102757 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 cat, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_083001 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 cat, 63.1ms
# Speed: 1.5ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_2948 - Sushada Saoun.jpeg
#
# 0: 480x640 2 persons, 1 horse, 1 bottle, 67.6ms
# Speed: 1.7ms preprocess, 67.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_20250726_084731 - Khomson Satchasataporn.jpg
#
# 0: 640x480 1 person, 1 cat, 1 dog, 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# Processed IMG_20250726_121135 - Khomson Satchasataporn.jpg
#
# 0: 480x640 1 dog, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_9001.png
#
# 0: 480x640 1 dog, 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Processed IMG_9000.jpeg
# Prediction completed. Results saved to prediction_results.csv
